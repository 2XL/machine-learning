# %% [markdown]
# # # Predicting Diabetes

# %% [markdown]
# ## Import Libraries

# %%
import pandas 
import matplotlib.pyplot
import numpy

# do ploting inline instead of in a separate window
# %matplotlib inline

# %% [markdown]
# ## Load and review data

# %%
df = pandas.read_csv("./data/pima-data.csv")
df.shape
# Out:
# (768, 10)

# %%
lines = 5
df.head(lines)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>num_preg</th>
#       <th>glucose_conc</th>
#       <th>diastolic_bp</th>
#       <th>thickness</th>
#       <th>insulin</th>
#       <th>bmi</th>
#       <th>diab_pred</th>
#       <th>age</th>
#       <th>skin</th>
#       <th>diabetes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>6</td>
#       <td>148</td>
#       <td>72</td>
#       <td>35</td>
#       <td>0</td>
#       <td>33.6</td>
#       <td>0.627</td>
#       <td>50</td>
#       <td>1.3790</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>85</td>
# ...

# %%
df.tail(lines)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>num_preg</th>
#       <th>glucose_conc</th>
#       <th>diastolic_bp</th>
#       <th>thickness</th>
#       <th>insulin</th>
#       <th>bmi</th>
#       <th>diab_pred</th>
#       <th>age</th>
#       <th>skin</th>
#       <th>diabetes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>763</th>
#       <td>10</td>
#       <td>101</td>
#       <td>76</td>
#       <td>48</td>
#       <td>180</td>
#       <td>32.9</td>
#       <td>0.171</td>
#       <td>63</td>
#       <td>1.8912</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>764</th>
#       <td>2</td>
#       <td>122</td>
# ...

# %%
df.isnull().values.any()
# Out:
# False

# %%
def plot_corr(df, size=11):
    """
    Function plots a graphical correlation matrix for each pair of columns in the dataframe.
    
    Input:
        
    :param df: pandas data frame 
    :param size: vertical and horizontal size of the plot
    
    
    :return: 
    
    
    
    Displays:
        matrix of correlations between columns.
            Blue-cyan-yello-red-darkred => less to more correlated
            0 ----------------------> 1
            Expect a darkred line running from top left to bottom right

    """
    
    corr = df.corr() # data frame correlation function
    fig, ax = matplotlib.pyplot.subplots(figsize=(size, size))
    ax.matshow(corr)
    matplotlib.pyplot.xticks(range(len(corr.columns)), corr.columns) # draw x tick marks
    matplotlib.pyplot.yticks(range(len(corr.columns)), corr.columns) # draw y tick marks

# %% [markdown]
# ## Candidate Algorithms
# - Naive Bayes:
# 	- based on likelihood and probability
# 	- every feature has the same weight
# 	- requires smaller amount of data
# - Logistic Regression:
# 	- confusing name, binary result
# 	- relation between features are weighted
# - Decision Tree
# 	- Binary tree
# 	- Node contains decision
# 	- Requires enough data to determine nodes and splits

# %% [markdown]
# ## Selected Algorithm: Naïve Bayes

# %% [markdown]
# - Simple - easy to understand
# - Fast - up to 100x faster
# - Stable - to data changes

# %% [markdown]
# ## Lots of algorithms available
# - Select based on
# 	1. Learning vs Supervised
# 	2. Result vs Binary Classification
# 	3. Non-ensemble
# 	4. Basic

# %%
# Out:
# 268
# 500
# Number of True cases 268 (34.90%)
# Number of False cases 500 (65.10%)
